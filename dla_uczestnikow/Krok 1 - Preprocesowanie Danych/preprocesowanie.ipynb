# %% [markdown]
# # Narzędzia do obróbki danych

# %% [markdown]
# ## Importowanie bibliotek

# %% [markdown]
# ## Importowanie Zbioru Danych

# %% [markdown]
# ## Produkowanie Brakujących danych

# %% [markdown]
# ## Kodowanie Zmiennych Kategorycznych

# %% [markdown]
# ### Kodowanie Zmiennej Niezależnej

# %% [markdown]
# ### Kodowanie Zmiennej Zależnej

# %% [markdown]
# ## Dzielenie Zbioru na Zbiory Treningowe i Testowe

# %% [markdown]
# ## Skalowanie Zmiennych
