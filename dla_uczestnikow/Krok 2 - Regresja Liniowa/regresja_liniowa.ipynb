# %% [markdown]
# # Regresja Liniowa

# %% [markdown]
# ## Importowanie bibliotek

# %% [markdown]
# ## Importowanie Zbioru Danych

# %% [markdown]
# ## Dzielenie Zbioru na Zbiory Treningowe i Testowe

# %% [markdown]
# ## Trenowanie Regresji Liniowej na Zbiorze Treningowym

# %% [markdown]
# ## Przewidywanie Wyników ze Zbioru Testowego

# %% [markdown]
# ## Wizualizacja Wyników Zbioru Treningowego

# %% [markdown]
# ## Wizualizacja Wyników Zbioru Testowego
