# %% [markdown]
# # Losowy Las Decyzyjny

# %% [markdown]
# ## Importowanie bibliotek

# %% [markdown]
# ## Importowanie Zbioru Danych

# %% [markdown]
# ## Trenowanie Modelu Random Forest na Całym Zbiorze Danych

# %% [markdown]
# ## Przewidywanie Wyników z Nowych Danych

# %% [markdown]
# ## Wizualizacja Wyników Lasu Decyzyjnego (wyższa rozdzielczość)
