# %% [markdown]
# # Regresyjne Drzewa Decyzyjne

# %% [markdown]
# ## Importowanie bibliotek

# %% [markdown]
# ## Importowanie Zbioru Danych

# %% [markdown]
# ## Trenowanie Drzewa na Całym Zbiorze Danych

# %% [markdown]
# ## Przewidywanie Wyników z Nowych Danych

# %% [markdown]
# ## Wizualizacja Wyników Drzewa Decyzyjnego (wyższa rozdzielczość)
