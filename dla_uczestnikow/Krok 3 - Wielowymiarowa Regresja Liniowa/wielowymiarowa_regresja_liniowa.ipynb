# %% [markdown]
# # Wielowymiarowa Regresja Liniowa

# %% [markdown]
# ## Importowanie bibliotek

# %% [markdown]
# ## Importowanie Zbioru Danych

# %% [markdown]
# ## Kodowanie Zmiennych Kategorycznych

# %% [markdown]
# ## Dzielenie Zbioru na Zbiory Treningowe i Testowe

# %% [markdown]
# ## Trenowanie Wielowymiarowej Regresji Liniowej na Zbiorze Treningowym

# %% [markdown]
# ## Przewidywanie Wyników ze Zbioru Testowego
